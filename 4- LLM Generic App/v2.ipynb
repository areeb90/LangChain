# %%
# !pip install -q langchain langchain-openai langchain-pinecone pinecone python-dotenv
# Out:
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
import os
from dotenv import load_dotenv
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings

load_dotenv()

# Set OpenAI and Pinecone API keys (or load from .env)
os.environ["OPENAI_API_KEY"] = "sk-proj-EROcWdHoy8v0czczzObUR1q6UMppUswl3UYhCuBVvaubhcBAxTLEwcK0-bY14byv42zyIKTKKmuFRRGJU6oA"
os.environ["PINECONE_API_KEY"] = "pcsk_mZP5S_RUVQ2oPAPHwiG9yVLenkZ3kcKD9pTKoNzZMGEaWLW6WkcSisQME3D6DJQdLjnKT"


loader = PyPDFDirectoryLoader("document/")
documents = loader.load()
print(f"Loaded {len(documents)} documents.")

splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
doc_chunks = splitter.split_documents(documents)
print(f"Split into {len(doc_chunks)} chunks.")
# Out:
# Loaded 13 documents.
# Split into 32 chunks.

# %%
# !pip uninstall -y pinecone pinecone-client
# Out:
# Found existing installation: pinecone 7.3.0
# Uninstalling pinecone-7.3.0:
#   Successfully uninstalled pinecone-7.3.0
# Found existing installation: pinecone-client 2.2.4
# Uninstalling pinecone-client-2.2.4:
#   Successfully uninstalled pinecone-client-2.2.4
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)

# %%
# !pip install pinecone-client
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
# !pip uninstall -y pinecone pinecone-client
# Out:
# Found existing installation: pinecone-client 6.0.0
# Uninstalling pinecone-client-6.0.0:
#   Successfully uninstalled pinecone-client-6.0.0
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Skipping pinecone as it is not installed.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)

# %%
# !pip install pinecone-client==2.2.4
# Out:
# ...
#   Using cached pinecone_client-2.2.4-py3-none-any.whl.metadata (7.8 kB)
# ...
# Using cached pinecone_client-2.2.4-py3-none-any.whl (179 kB)
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
import pinecone
# Check Pinecone version
from importlib.metadata import version
print(version("pinecone-client"))
# Out:
# 2.2.4

# %%
import pinecone
print(pinecone.__file__)
# Out:
# c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py

# %%
import os
from pinecone import Pinecone, ServerlessSpec

# Initialize Pinecone (use environment variable for API key)
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY", "pcsk_mZP5S_RUVQ2oPAPHwiG9yVLenkZ3kcKD9pTKoNzZMGEaWLW6WkcSisQME3D6DJQdLjnKT"))

index_name = "langchainvector"

# Check if index exists and create if needed
existing_indexes = [index.name for index in pc.list_indexes()]

if index_name not in existing_indexes:
    pc.create_index(
        name=index_name,
        dimension=1536,  # Adjust based on your embedding model
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# Connect to the index
index = pc.Index(index_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 2
#       1 import os
# ----> 2 from pinecone import Pinecone, ServerlessSpec
#       4 # Initialize Pinecone (use environment variable for API key)
#       5 pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY", "pcsk_mZP5S_RUVQ2oPAPHwiG9yVLenkZ3kcKD9pTKoNzZMGEaWLW6WkcSisQME3D6DJQdLjnKT"))
#
# ImportError: cannot import name 'Pinecone' from 'pinecone' (c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py)

# %%
import os
from pinecone import Pinecone, ServerlessSpec

# Initialize Pinecone
# It's best practice to pass the API key this way.
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

index_name = "langchainvector"

# Check if index exists and create if needed
existing_indexes = pc.list_indexes().names

if index_name not in existing_indexes:
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# Connect to the index
index = pc.Index(index_name)

# You can now use the 'index' object to upsert, query, etc.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 2
#       1 import os
# ----> 2 from pinecone import Pinecone, ServerlessSpec
#       4 # Initialize Pinecone
#       5 # It's best practice to pass the API key this way.
#       6 pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
#
# ImportError: cannot import name 'Pinecone' from 'pinecone' (c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py)

# %%
import pinecone
print(pinecone.__file__)
# Out:
# c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py

# %%
# !pip uninstall -y pinecone pinecone-client
# !pip cache purge
# Out:
# Found existing installation: pinecone-client 2.2.4
# Uninstalling pinecone-client-2.2.4:
#   Successfully uninstalled pinecone-client-2.2.4
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Skipping pinecone as it is not installed.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# Files removed: 16 (849 kB)

# %%
# !pip install pinecone-client==2.2.4
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
import pinecone
print(pinecone.__file__)
# Out:
# c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py

# %%
# !pip uninstall pinecone-client -y
# Out:
# Found existing installation: pinecone-client 2.2.4
# Uninstalling pinecone-client-2.2.4:
#   Successfully uninstalled pinecone-client-2.2.4
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)

# %%
# !pip install -U pinecone
# Out:
# ...
#    ---------------------------------------- 0.0/587.6 kB ? eta -:--:--
#    ---------------------------------------- 587.6/587.6 kB 6.9 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
from importlib.metadata import version
print(version("pinecone"))
# Out:
# 7.3.0

# %%
# !pip uninstall -y pinecone-client pinecone
# Out:
# Found existing installation: pinecone 7.3.0
# Uninstalling pinecone-7.3.0:
#   Successfully uninstalled pinecone-7.3.0
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Skipping pinecone-client as it is not installed.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)

# %%
# !pip install pinecone
# Out:
# ...
#   Using cached pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# ...
# Using cached pinecone-7.3.0-py3-none-any.whl (587 kB)
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
# !pip uninstall pinecone -y
# !pip uninstall pinecone-client -y
# !pip cache purge
# !pip install pinecone-client
# Out:
# Found existing installation: pinecone 7.3.0
# Uninstalling pinecone-7.3.0:
#   Successfully uninstalled pinecone-7.3.0
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\khanz\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\khanz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Skipping pinecone-client as it is not installed.
# Files removed: 12 (836 kB)
# ...

# %%
# !python -c "from pinecone import Pinecone; print('Success!')"
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py", line 5, in <module>
#     raise Exception(
# Exception: The official Pinecone python package has been renamed from `pinecone-client` to `pinecone`. Please remove `pinecone-client` from your project dependencies and add `pinecone` instead. See the README at https://github.com/pinecone-io/pinecone-python-client for more information on using the python SDK.

# %%
pc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pc
#
# NameError: name 'pc' is not defined

# %%
from pinecone import Pinecone
print("✅ Pinecone v3 SDK loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from pinecone import Pinecone
#       2 print("✅ Pinecone v3 SDK loaded successfully")
#
# ImportError: cannot import name 'Pinecone' from 'pinecone' (c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py)

# %%
from pinecone import Pinecone
pc = Pinecone(api_key="pcsk_mZP5S_RUVQ2oPAPHwiG9yVLenkZ3kcKD9pTKoNzZMGEaWLW6WkcSisQME3D6DJQdLjnKT")
print("✅ Pinecone v3 SDK loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from pinecone import Pinecone
#       2 pc = Pinecone(api_key="pcsk_mZP5S_RUVQ2oPAPHwiG9yVLenkZ3kcKD9pTKoNzZMGEaWLW6WkcSisQME3D6DJQdLjnKT")
#       3 print("✅ Pinecone v3 SDK loaded successfully")
#
# ImportError: cannot import name 'Pinecone' from 'pinecone' (c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pinecone\__init__.py)

# %%
from langchain_pinecone import PineconeVectorStore
from langchain.embeddings.openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

vectorstore = PineconeVectorStore.from_documents(
    documents=doc_chunks,
    embedding=embeddings,
    index_name="langchainvector",
    namespace="default"
)

print("✅ Documents successfully uploaded to Pinecone.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from langchain_pinecone import PineconeVectorStore
#       2 from langchain.embeddings.openai import OpenAIEmbeddings
#       4 embeddings = OpenAIEmbeddings()
#
# File c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_pinecone\__init__.py:1
# ----> 1 from langchain_pinecone.embeddings import PineconeEmbeddings, PineconeSparseEmbeddings
#       2 from langchain_pinecone.rerank import PineconeRerank
#       3 from langchain_pinecone.vectorstores import Pinecone, PineconeVectorStore
#
# File c:\Users\khanz\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_pinecone\embeddings.py:6
#       4 from langchain_core.embeddings import Embeddings
#       5 from langchain_core.utils import secret_from_env
# ...

# %%
query = "What is this PDF about?"
results = vectorstore.similarity_search(query, k=3)

for i, res in enumerate(results, 1):
    print(f"\nResult {i}:")
    print("Text:", res.page_content)
    print("Metadata:", res.metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 query = "What is this PDF about?"
# ----> 2 results = vectorstore.similarity_search(query, k=3)
#       4 for i, res in enumerate(results, 1):
#       5     print(f"\nResult {i}:")
#
# NameError: name 'vectorstore' is not defined
